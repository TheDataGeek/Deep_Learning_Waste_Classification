# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from os import path
from glob import glob
from tqdm import tqdm

from sklearn import ensemble
from sklearn import metrics
from sklearn import preprocessing
from sklearn.decomposition import PCA

from tensorflow import keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Activation, Conv2D, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# create directory paths for images (from dataset)
base_dir = '../01_data/COMPLETE_DATASET'
train_dir = path.join(base_dir, 'TRAIN')
test_dir = path.join(base_dir, 'TEST')

print(train_dir)
print(test_dir)
# Out:
# ../01_data/COMPLETE_DATASET/TRAIN
# ../01_data/COMPLETE_DATASET/TEST

# %%
# .jpg files of organic images from train data
train_org = glob(path.join(train_dir, 'O', '*.jpg'))
print('Number of organic (train) images: ', len(train_org))
# Out:
# Number of organic (train) images:  12565

# %%
# .jpg files of recyclable images from train data
train_re = glob(path.join(train_dir, 'R', '*.jpg'))
print('Number of recyclable (train) images: ', len(train_re))
# Out:
# Number of recyclable (train) images:  9999

# %%
# .jpg files of organic images from train data
test_org = glob(path.join(test_dir, 'O', '*.jpg'))
print('Number of organic (test) images: ', len(test_org))
# Out:
# Number of organic (test) images:  1401

# %%
# .jpg files of organic images from train data
test_re = glob(path.join(test_dir, 'R', '*.jpg'))
print('Number of recyclable (test) images: ', len(test_re))
# Out:
# Number of recyclable (test) images:  1112

# %%
print('Number of total (train + test) images: ', len(train_org)+len(train_re)+len(test_org)+len(test_re))
print('Number of train (organic + recyclable) images: ', len(train_org)+len(train_re))
print('Number of test (organic + recyclable) images: ', len(test_org)+len(test_re))
# Out:
# Number of total (train + test) images:  25077
# Number of train (organic + recyclable) images:  22564
# Number of test (organic + recyclable) images:  2513

# %%
x_data = []
y_data = []

for folder in glob(path.join(train_dir, '*')):
    for file in tqdm(glob(path.join(folder, '*.jpg'))):
        img_array = plt.imread(file)
        x_data.append(img_array)
        y_data.append(folder.split('/')[-1])

train_data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 9999/9999 [00:14<00:00, 693.50it/s]
# 100%|██████████████████████████████████████████████████████████████████| 12565/12565 [00:19<00:00, 642.79it/s]

# %%
train_data.shape
# Out:
# (22564, 2)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22564 entries, 0 to 22563
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   22564 non-null  object
#  1   label   22564 non-null  object
# dtypes: object(2)
# memory usage: 352.7+ KB

# %%
# pie chart of classes

plt.figure(figsize=(8,8))
plt.pie(train_data.label.value_counts(), 
        explode=[0.025,0.025],
        colors=['yellowgreen', 'tomato'],
        labels=['Organic', 'Recyclable'],
        autopct='%.2f%%',
        startangle=90,
        textprops={'fontsize':12})
plt.show();

# %%
# read and display organic image
plt.imshow(plt.imread(train_org[8]))

# %%
# read and display recyclable images
plt.imshow(plt.imread(train_re[1]))

# %%
plt.figure(figsize=(20,15))
for i in range(9):
    plt.subplot(3,3,(i%12)+1)
    index=np.random.randint(22000)
    
    plt.imshow(train_data.image[index])
    plt.axis('off')
    
    if train_data.label[index] == 'O':
        plt.title('Organic Waste', fontdict={'size':24})
    else:
        plt.title('Recycable Waste', fontdict={'size':24})
    
plt.show()

# %%
# return shape for first 10 organic images
for img in train_org[0:10]:
    print((plt.imread(img)).shape)
# Out:
# (225, 225, 3)
# (224, 224, 3)
# (191, 264, 3)
# (168, 300, 3)
# (183, 276, 3)
# (240, 210, 3)
# (194, 259, 3)
# (195, 258, 3)
# (183, 275, 3)
# (183, 276, 3)

# %%
# return shape for first 10 recyclable images
for img in train_re[0:10]:
    print((plt.imread(img)).shape)
# Out:
# (168, 300, 3)
# (218, 231, 3)
# (225, 225, 3)
# (133, 380, 3)
# (177, 284, 3)
# (177, 285, 3)
# (267, 189, 3)
# (169, 297, 3)
# (275, 183, 3)
# (275, 183, 3)

# %%
# image augmentation
data_generator = ImageDataGenerator(rescale = 1.0 / 255.0)

# %%
# train data
train_generator = data_generator.flow_from_directory(
    train_dir,
    class_mode='binary',
    batch_size=32,
    seed=42)
# Out:
# Found 22564 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'O': 0, 'R': 1}

# %%
# test data
test_generator = data_generator.flow_from_directory(
    test_dir, 
    class_mode='binary',
    batch_size=32,
    seed=42)
# Out:
# Found 2513 images belonging to 2 classes.

# %%
# assign x and y values
x_train, y_train = next(train_generator)
x_test, y_test = next(test_generator)

# %%
x_train.ndim
# Out:
# 4

# %%
print(x_train.shape)
# Out:
# (32, 256, 256, 3)

# %%
print(y_train.shape)
# Out:
# (32,)

# %% [markdown]
# ## NON DEEP LEARNING MODEL (RANDOM FOREST)

# %%
# reshape x_train values; sklearn expects 2D array
nsamples, nx, ny, nrgb = x_train.shape
x_train_2d = x_train.reshape((nsamples,nx*ny*nrgb))

# %%
# reshape x_test values; sklearn expects 2D array
nsamples, nx, ny, nrgb = x_test.shape
x_test_2d = x_test.reshape((nsamples,nx*ny*nrgb))

# %%
# reduce train data dimensions using PCA
pca = PCA(n_components=2)
pca.fit(x_train_2d)
pcafeatures_train = pca.transform(x_train_2d)

# %%
np.shape(pcafeatures_train)
# Out:
# (32, 2)

# %%
# reduce test data dimensions using PCA
pca = PCA(n_components=2)
pca.fit(x_test_2d)
pcafeatures_test = pca.transform(x_test_2d)

# %%
# instantiate and fit baseline model
rf = ensemble.RandomForestRegressor(n_estimators=100)

rf.fit(pcafeatures_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# evaluate random forest
rf_y_pred = rf.predict(pcafeatures_test)

# %%
# evaluate
print(f"Random Forest MAE: {metrics.mean_absolute_error(y_test, rf_y_pred):,.4f}")
print(f"Random Forest MSE: {metrics.mean_squared_error(y_test, rf_y_pred):,.4f}")
# Out:
# Random Forest MAE: 0.2388
# Random Forest MSE: 0.1293

# %% [markdown]
# ### SIMPLE NEURAL NET

# %%
snn = Sequential()

snn.add(Flatten(input_shape=x_train.shape[1:]))
snn.add(Dense(units=80, activation='relu'))
snn.add(Dense(units=40, activation='relu'))
snn.add(Dense(units=20, activation='relu'))
snn.add(Dense(units=10, activation='relu'))
snn.add(Dense(units=1, activation='sigmoid'))

snn.compile('sgd', loss='mean_absolute_error', metrics=['mean_squared_error'])
snn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 196608)            0
#
#  dense (Dense)               (None, 80)                15728720
#
#  dense_1 (Dense)             (None, 40)                3240
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 15,733,001
# Trainable params: 15,733,001
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-06 16:25:35.711016: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
snn.fit(x_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5121 - mean_squared_error: 0.2672
# Epoch 2/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5044 - mean_squared_error: 0.2553
# Epoch 3/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4534 - mean_squared_error: 0.2290
# Epoch 4/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3610 - mean_squared_error: 0.2929
# Epoch 5/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3249 - mean_squared_error: 0.3106
# Epoch 6/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3208 - mean_squared_error: 0.3115
# Epoch 7/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3187 - mean_squared_error: 0.3118
# Epoch 8/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3175 - mean_squared_error: 0.3120
# Epoch 9/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3167 - mean_squared_error: 0.3121
# Epoch 10/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3162 - mean_squared_error: 0.3122
# Epoch 11/20
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3157 - mean_squared_error: 0.3123
# Epoch 12/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3154 - mean_squared_error: 0.3123
# Epoch 13/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3151 - mean_squared_error: 0.3123
# Epoch 14/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3149 - mean_squared_error: 0.3123
# Epoch 15/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3147 - mean_squared_error: 0.3124
# Epoch 16/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3146 - mean_squared_error: 0.3124
# Epoch 17/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3144 - mean_squared_error: 0.3124
# Epoch 18/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3143 - mean_squared_error: 0.3124
# Epoch 19/20
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3142 - mean_squared_error: 0.3124
# Epoch 20/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3141 - mean_squared_error: 0.3124

# %%
# evaluate simple neural net model
snn.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 0s 127ms/step - loss: 0.3141 - mean_squared_error: 0.3123
# [0.3140515983104706, 0.3122883141040802]

# %%
# evaluate simple neural net model
snn_y_pred = snn.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 85ms/step

# %%
print(f"Simple Neural Net MAE: {metrics.mean_absolute_error(y_test, snn_y_pred):,.4f}")
print(f"Simple Neural Net MSE: {metrics.mean_squared_error(y_test, snn_y_pred):,.4f}")
# Out:
# Simple Neural Net MAE: 0.3141
# Simple Neural Net MSE: 0.3123
